# %%
# !nvidia-smi
# Out:
# Mon Jan 31 14:16:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import zipfile

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path_zip = 'drive/MyDrive/kinetics400.zip'
z = zipfile.ZipFile(path_zip, 'r')
z.extractall()

# %%
# !git clone https://github.com/Vlad15lav/vu-crw-segmentation.git
# Out:
# Cloning into 'vu-crw-segmentation'...
# remote: Enumerating objects: 395, done.
# remote: Counting objects: 100% (395/395), done.
# remote: Compressing objects: 100% (365/365), done.
# remote: Total 395 (delta 185), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (395/395), 20.33 MiB | 3.39 MiB/s, done.
# Resolving deltas: 100% (185/185), done.

# %%
# %cd vu-crw-segmentation/
# Out:
# /content/vu-crw-segmentation

# %%
# !ls
# Out:
# data  models  papers  README.md  requirements.txt  test.py  train_crw.py  utils

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 13.1 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 27.4 MB/s
# ...
#      |████████████████████████████████| 36.1 MB 2.2 MB/s
# ...
#      |████████████████████████████████| 60.4 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 13.3 MB 27.4 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 43.3 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 41.3 MB/s
# ...
#      |████████████████████████████████| 676 kB 42.3 MB/s
# ...
#      |████████████████████████████████| 895 kB 44.1 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 41.8 MB/s
# ...
#      |████████████████████████████████| 143 kB 50.0 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 180 kB 50.7 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.0 MB/s
# ...

# %%
# !python train_crw.py --data-path ../kinetics400 --weight-path ../drive/MyDrive/training_crw/ --cache-path ../drive/MyDrive/training_crw/ --augs grid --bs 6 --adam
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:853: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# 100% 3/3 [00:53<00:00, 17.68s/it]
# 100% 1/1 [00:07<00:00,  7.33s/it]
# (epoche 1): train loss: 1.8044477488126671, train accuracy: 0.47142407298088074, valid loss: 1.8196037996162489, valid accuracy: 0.456046462059021
# (epoche 2): train loss: 1.6634518739424253, train accuracy: 0.5178123712539673, valid loss: 1.810005978473182, valid accuracy: 0.46758803725242615
# (epoche 3): train loss: 1.6167347033818562, train accuracy: 0.5343119502067566, valid loss: 1.8703488423986343, valid accuracy: 0.4602569043636322
# (epoche 4): train loss: 1.5584350965524976, train accuracy: 0.5518483519554138, valid loss: 1.7143962568449742, valid accuracy: 0.5146291255950928
# ...
